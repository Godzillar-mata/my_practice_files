# %% [markdown]
# *** Exercise : Preview dataframe
# - 1.import CSV/Excel/JSON file
# - 2.Preview dataframe + observing dataframe info.
# - 3.Show dataframe with 1 condition without replace original dataframe.
# - 4.show dataframe with 2 or more conditions without replace original dataframe.
# ** statistic describing using Pandas.
# - 5.show statistic values.
# - 6.rename column.
# - 7.describe value without null values.
# - 8.describe value with all values.
# - 9.describe specific statistic values.
# - 10.show statistic value for 1 specific column.
# - 11.show statistic value for every columns (make a group by).
# - 12.show all statistic values for 1 specific column.
# - 13.show all statistic values for every columns (make a group by).
# ** statistic describing using Numpy.
# - 14.show statistic value for 1 specific column using numpy.
# - 15.show statistic value for every columns (make a group by) using numpy.
# - 16.show all statistic values for 1 specific column using numpy.
# - 17.show all statistic values for every columns (make a group by) using numpy.
# ** Create visualizations
# - 18.create visualizations using Matplotlib.
# - 19.create visualizations using Seaborn.

# %%
import pandas as pd
## 1. import CSV/Excel/JSON file
df = pd.read_csv(r"D:\Python work\ส่วนตัว\python practice\Data for practice\Cleaned data\airlines_flights_data.csv")
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
## 2.Preview dataframe + observing dataframe info.
## Preview dataframe
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.tail()
# Out:
#          index  airline  flight source_city departure_time stops arrival_time  \
# 300148  300148  Vistara  UK-822     Chennai        Morning   one      Evening
# 300149  300149  Vistara  UK-826     Chennai      Afternoon   one        Night
# 300150  300150  Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151  300151  Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152  300152  Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 300148        Hyderabad  Business     10.08         49  69265
# 300149        Hyderabad  Business     10.42         49  77105
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585

# %%
df.shape
# Out:
# (300153, 12)

# %% [markdown]
# shape showed this dataframe has 300153 rows and 12 columns

# %%
## Dataframe info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %% [markdown]
# dataframe info. showed there is no null value in this dataframe and also show column data type.

# %%
## 3.Show dataframe with 1 condition without replace original dataframe.
df_night = df[df["arrival_time"] == "Night"]
df_night.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91538 entries, 0 to 300150
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             91538 non-null  int64
#  1   airline           91538 non-null  object
#  2   flight            91538 non-null  object
#  3   source_city       91538 non-null  object
#  4   departure_time    91538 non-null  object
#  5   stops             91538 non-null  object
#  6   arrival_time      91538 non-null  object
#  7   destination_city  91538 non-null  object
#  8   class             91538 non-null  object
#  9   duration          91538 non-null  float64
#  10  days_left         91538 non-null  int64
#  11  price             91538 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 9.1+ MB

# %%
## 4.show dataframe with 2 or more conditions without replace original dataframe.
## showing AirAsia Economy class which night arrival time.
df_AirAsia_business_night = df[
    (df["airline"] == "AirAsia") & 
    (df["class"] == "Economy") & 
    (df["arrival_time"] == "Night")
]

df_AirAsia_business_night.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3477 entries, 1323 to 202569
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             3477 non-null   int64
#  1   airline           3477 non-null   object
#  2   flight            3477 non-null   object
#  3   source_city       3477 non-null   object
#  4   departure_time    3477 non-null   object
#  5   stops             3477 non-null   object
#  6   arrival_time      3477 non-null   object
#  7   destination_city  3477 non-null   object
#  8   class             3477 non-null   object
#  9   duration          3477 non-null   float64
#  10  days_left         3477 non-null   int64
#  11  price             3477 non-null   int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 353.1+ KB

# %%
## !!! more tips : show distinct value of each column
df_unique_airline = df[["airline"]].drop_duplicates()
df_unique_source_city = df[["source_city"]].drop_duplicates()
df_unique_departure_time = df[["departure_time"]].drop_duplicates()
df_unique_stops = df[["stops"]].drop_duplicates()
df_unique_arrival_time = df[["arrival_time"]].drop_duplicates()
df_unique_destination_city = df[["destination_city"]].drop_duplicates()
df_unique_class = df[["class"]].drop_duplicates() 

print(df_unique_airline)
# Out:
#       airline
# 0    SpiceJet
# 2     AirAsia
# 3     Vistara
# 8    GO_FIRST
# 12     Indigo
# 16  Air_India

# %%
print(df_unique_source_city)
# Out:
#        source_city
# 0            Delhi
# 43027       Mumbai
# 84065    Bangalore
# 119685     Kolkata
# 152559   Hyderabad
# 180495     Chennai

# %%
print(df_unique_departure_time)
# Out:
#      departure_time
# 0           Evening
# 1     Early_Morning
# 3           Morning
# 7         Afternoon
# 40            Night
# 1671     Late_Night

# %%
print(df_unique_stops)
# Out:
#            stops
# 0           zero
# 18           one
# 175  two_or_more

# %%
print(df_unique_arrival_time)
# Out:
#       arrival_time
# 0            Night
# 1          Morning
# 2    Early_Morning
# 3        Afternoon
# 7          Evening
# 193     Late_Night

# %%
print(df_unique_destination_city)
# Out:
#       destination_city
# 0               Mumbai
# 9982         Bangalore
# 20126          Kolkata
# 28780        Hyderabad
# 35361          Chennai
# 43027            Delhi

# %%
print(df_unique_class)
# Out:
#            class
# 0        Economy
# 206666  Business

# %%
## 5. show statistic values.
df["duration"].mean()
# Out:
# np.float64(12.221020812718846)

# %%
## 6. rename column.
df_rename = df.rename(columns={
    "flight" : "flight_name",
    "class" : "flight_class",
    "stops" : "stop_points"
    })

df_rename
# Out:
#          index   airline flight_name source_city departure_time stop_points  \
# 0            0  SpiceJet     SG-8709       Delhi        Evening        zero
# 1            1  SpiceJet     SG-8157       Delhi  Early_Morning        zero
# 2            2   AirAsia      I5-764       Delhi  Early_Morning        zero
# 3            3   Vistara      UK-995       Delhi        Morning        zero
# 4            4   Vistara      UK-963       Delhi        Morning        zero
# ...        ...       ...         ...         ...            ...         ...
# 300148  300148   Vistara      UK-822     Chennai        Morning         one
# 300149  300149   Vistara      UK-826     Chennai      Afternoon         one
# 300150  300150   Vistara      UK-832     Chennai  Early_Morning         one
# 300151  300151   Vistara      UK-828     Chennai  Early_Morning         one
# 300152  300152   Vistara      UK-822     Chennai        Morning         one
#
# ...

# %%
# 7. describe value without null values.
df.describe()
# Out:
#                index       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
# !!! Determined decimal place to make number look more clearer
df.describe().round(2)
# Out:
#            index   duration  days_left      price
# count  300153.00  300153.00  300153.00  300153.00
# mean   150076.00      12.22      26.00   20889.66
# std     86646.85       7.19      13.56   22697.77
# min         0.00       0.83       1.00    1105.00
# 25%     75038.00       6.83      15.00    4783.00
# 50%    150076.00      11.25      26.00    7425.00
# 75%    225114.00      16.17      38.00   42521.00
# max    300152.00      49.83      49.00  123071.00

# %%
# 8. describe value with all values.
df.describe(include="all")

# !! Note : This will show statistic values of all column include numeric and string column.
# Out:
#                 index  airline  flight source_city departure_time   stops  \
# count   300153.000000   300153  300153      300153         300153  300153
# unique            NaN        6    1561           6              6       3
# top               NaN  Vistara  UK-706       Delhi        Morning     one
# freq              NaN   127859    3235       61343          71146  250863
# mean    150076.000000      NaN     NaN         NaN            NaN     NaN
# std      86646.852011      NaN     NaN         NaN            NaN     NaN
# min          0.000000      NaN     NaN         NaN            NaN     NaN
# 25%      75038.000000      NaN     NaN         NaN            NaN     NaN
# 50%     150076.000000      NaN     NaN         NaN            NaN     NaN
# 75%     225114.000000      NaN     NaN         NaN            NaN     NaN
# max     300152.000000      NaN     NaN         NaN            NaN     NaN
#
#        arrival_time destination_city    class       duration      days_left  \
# ...

# %%
# 9. describe specific statistic values.
df["days_left"].mean()
# Out:
# np.float64(26.004750910369044)

# %%
# 10.show statistic value for 1 specific column.
df_duration_mean = df["duration"].mean()
df_duration_median = df["duration"].median()
df_duration_max = df["duration"].max()
df_duration_min = df["duration"].min()

print(df_duration_mean)
print(df_duration_median)
print(df_duration_max)
print(df_duration_min)
# Out:
# 12.221020812718846
# 11.25
# 49.83
# 0.83

# %%
# 11.show statistic value for every columns (make a group by).
df.groupby("airline")["duration"].mean()
# Out:
# airline
# AirAsia       8.941714
# Air_India    15.504235
# GO_FIRST      8.755380
# Indigo        5.795197
# SpiceJet     12.579767
# Vistara      13.326634
# Name: duration, dtype: float64

# %%
# !! Note : we can show specific multiple statistic values by using this code
df.groupby("airline")["duration"].agg(["median", "max", "min"])
# Out:
#            median    max   min
# airline
# AirAsia      9.33  19.58  0.92
# Air_India   15.00  49.83  1.00
# GO_FIRST     8.83  22.50  1.00
# Indigo       6.00  15.42  0.83
# SpiceJet    12.00  27.92  1.00
# Vistara     12.50  47.08  1.00

# %%
# 12.show all statistic values for 1 specific column.
df["duration"].describe(include="all")
# Out:
# count    300153.000000
# mean         12.221021
# std           7.191997
# min           0.830000
# 25%           6.830000
# 50%          11.250000
# 75%          16.170000
# max          49.830000
# Name: duration, dtype: float64

# %%
# 13.show all statistic values for every columns (make a group by).
df.groupby("airline")["duration"].describe(include="all")
# Out:
#               count       mean       std   min    25%    50%    75%    max
# airline
# AirAsia     16098.0   8.941714  4.173152  0.92   5.92   9.33  11.83  19.58
# Air_India   80892.0  15.504235  7.613365  1.00  10.08  15.00  21.67  49.83
# GO_FIRST    23173.0   8.755380  4.015146  1.00   6.00   8.83  11.75  22.50
# Indigo      43120.0   5.795197  2.769322  0.83   2.92   6.00   7.75  15.42
# SpiceJet     9011.0  12.579767  8.927157  1.00   2.83  12.00  21.08  27.92
# Vistara    127859.0  13.326634  6.777230  1.00   8.50  12.50  17.00  47.08

# %%
# 14. - 17.show statistic value using numpy.
import numpy as np
df.groupby("airline")["duration"].agg([
    ("mean", np.mean),
    ("median", np.median),
    ("min", np.min),
    ("max", np.max),
    ("std.", np.std),
    ("25%", lambda x : np.percentile(x, 25)),
    ("75%", lambda x : np.percentile(x, 75)),
    ("count", len)
])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19368\3484904259.py:3: FutureWarning: The provided callable <function mean at 0x00000234ECE93F60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby("airline")["duration"].agg([
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19368\3484904259.py:3: FutureWarning: The provided callable <function median at 0x00000234ECFDF4C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("airline")["duration"].agg([
# ...

# %%
print(f"airline : {df["airline"].unique()}")
print(f"source_city : {df["source_city"].unique()}")
print(f"stops : {df["stops"].unique()}")
print(f"destination_city : {df["destination_city"].unique()}")
print(f"class : {df["class"].unique()}")
# Out:
# airline : ['SpiceJet' 'AirAsia' 'Vistara' 'GO_FIRST' 'Indigo' 'Air_India']
# source_city : ['Delhi' 'Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai']
# stops : ['zero' 'one' 'two_or_more']
# destination_city : ['Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai' 'Delhi']
# class : ['Economy' 'Business']

# %%
# Create visualizations
# 18.create visualizations using matplotlib. include : 1.histogram chart, 2.bar chart, 3.line chart, 4.pie chart, 5.Scatter plot 

# 1.histogram chart
# Histogram core syntax 
# plt.hist(
#     data, 
#     bins=20, 
#     color='purple', 
#     alpha=0.7
#     )              # alpha = transparency
# plt.title('Histogram')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.show()


import matplotlib.pyplot as plt
plt.hist(
    df[df["airline"] == "AirAsia"]["duration"], 
    bins = 10, 
    color = "blue", 
    alpha = 0.5, 
    edgecolor = "black"
    )
plt.title("AirAsia flight duration")
plt.xlabel("flight duration")
plt.ylabel("number of flight") 
plt.show()

# %%
import matplotlib.pyplot as plt
count, bin, patches = plt.hist(
    df[df["airline"] == "AirAsia"]["duration"], 
    bins = 10, 
    color = "blue", 
    alpha = 0.5, 
    edgecolor = "black"
    )
plt.title("AirAsia flight duration")
plt.xlabel("flight duration")
plt.ylabel("number of flight")

# ใส่ data labels

for hist_label in patches:
    height = hist_label.get_height()
    if height > 0:
        plt.text(
            hist_label.get_x() + hist_label.get_width()/2,
            height + 20,
            str(int(height)),
            ha = "center",
            va = "bottom"
        )

plt.show()

# %%
duration_groupby_airline = df.groupby("airline")["duration"].mean().sort_values(ascending=False)

print(duration_groupby_airline.index)
print(duration_groupby_airline.values)
# Out:
# Index(['Air_India', 'Vistara', 'SpiceJet', 'AirAsia', 'GO_FIRST', 'Indigo'], dtype='object', name='airline')
# [15.50423528 13.3266345  12.57976695  8.9417145   8.75537997  5.79519666]

# %%
# 2.bar chart
# bar chart core syntax
# plt.bar(
#    *category,
#    *value,
#    *color,
#    *width,
#    edgcolor
# )
# plt.title()
# plt.xlabel()
# plt.ylabel()
# plt.show()

import matplotlib.pyplot as plt

# Create the bar chart and store the bars
bars = plt.bar(
    duration_groupby_airline.index, 
    duration_groupby_airline.values, 
    color="green",
    width=0.5
)

plt.title("AirAsia flight duration in bar chart")
plt.xlabel("airline")
plt.ylabel("average flight duration")

# Add data labels
for bar in bars:
    bar_height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,  # x-position: center of the bar
        bar_height,                           # y-position: height of the bar
        str(round(bar_height, 1)),            # label text (1 decimal place)
        ha="center", 
        va="bottom"
    )

plt.show()

# %%
# 3.line chart
# line chart core syntax 
# plt.plot(
#     x,
#     y,
#     linestyle,
#     marker,
#     color,
#     label
# )
# plt.title()
# plt.xlabel()
# plt.ylabel()
# plt.show()

plt.plot(
    df["duration"],
    df["price"],
    linestyle = "-",
    marker = ".",
    color = "black",
    label = "price per flight duration"
)
plt.title("Relation between flight duration and price")
plt.xlabel("duration")
plt.ylabel("price")
plt.legend()
plt.show()

# %%
print(f"airline : {df["airline"].unique()}")
print(f"source_city : {df["source_city"].unique()}")
print(f"stops : {df["stops"].unique()}")
print(f"destination_city : {df["destination_city"].unique()}")
print(f"class : {df["class"].unique()}")
# Out:
# airline : ['SpiceJet' 'AirAsia' 'Vistara' 'GO_FIRST' 'Indigo' 'Air_India']
# source_city : ['Delhi' 'Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai']
# stops : ['zero' 'one' 'two_or_more']
# destination_city : ['Mumbai' 'Bangalore' 'Kolkata' 'Hyderabad' 'Chennai' 'Delhi']
# class : ['Economy' 'Business']

# %%
df.groupby("airline")["price"].count().sort_values(ascending=False)
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: price, dtype: int64

# %%
df.groupby("airline")["price"].mean().index
# Out:
# Index(['AirAsia', 'Air_India', 'GO_FIRST', 'Indigo', 'SpiceJet', 'Vistara'], dtype='object', name='airline')

# %%
# 4.pie chart
# piechart core Syntax
# plt.pie(
#     sizes,
#     labels,
#     color,
#     autopct,
#     startangle
# )
# plt.title()
# plt.show()

plt.pie(
    df.groupby("airline")["flight"].count().sort_values(ascending=True),
    labels = df.groupby("airline")["flight"].count().sort_values(ascending=False).index,
    colors = ["orange", "yellow", "blue", "green", "red", "purple"],
    autopct = "%1.1f%%",
    startangle = 90
)
plt.title("flight distribution")
plt.show()

# %%
# 5. scatter plot
# scatter plot core syntax
# plt.scatter(
#     x,
#     y,
#     color = "",
#     marker = "",
#     s = ...
# )
# plt.title("Relationship between duration and price")
# plt.xlabel("duration")
# plt.ylabel("price")
# plt.show()

import matplotlib.pyplot as plt

plt.scatter(
    df["duration"],
    df["price"],
    color = "purple",
    marker = ".",
    s = 50,
    alpha= 0.5
)
plt.title("Relationship between duration and price")
plt.xlabel("flight duration")
plt.ylabel("price")
plt.show()

# %%
# 19.create visualizations using Seaborn include : 1.histogram chart, 2.bar chart, 3.line chart, 4.pie chart, 5.Scatter plot 

# Seaborn core systax

# Chart Type	Function	        Minimal Example
# Histogram	    sns.histplot()	    sns.histplot(data=df, x="duration")
# Bar Chart	    sns.barplot()	    sns.barplot(data=df, x="airline", y="duration")
# Count Plot	sns.countplot()	    sns.countplot(data=df, x="airline")
# Scatter Plot	sns.scatterplot()	sns.scatterplot(data=df, x="duration", y="price")
# Line Plot	    sns.lineplot()	    sns.lineplot(data=df, x="date", y="price")
# Box Plot	    sns.boxplot()	    sns.boxplot(data=df, x="airline", y="duration")
# Violin Plot	sns.violinplot()	sns.violinplot(data=df, x="airline", y="duration")
# Heatmap	    sns.heatmap()	    sns.heatmap(corr_matrix, annot=True)

# %%
# 19.1 Seaborn : histogram

import matplotlib.pyplot as plt
import seaborn as sns

seaborn_hist = sns.histplot(
    data = df,                ### core
    x = df["duration"],       ### core
    bins = 10,
    color = "blue",
    edgecolor = "green",
    alpha = 0.3
)

for seaborn_hist_var in seaborn_hist.patches:
    seaborn_hist_height =  seaborn_hist_var.get_height()
    seaborn_hist.text(
        seaborn_hist_var.get_x() + seaborn_hist_var.get_width()/2,
        seaborn_hist_height + 50,
        str(int(seaborn_hist_height)),
        ha = "center",
        va = "bottom"
    )

plt.title("Flight duration distribution")
plt.xlabel("Flight duration")
plt.ylabel("number of flight")
plt.show()

# %%
dff = df.groupby("airline")["duration"].mean().sort_values(ascending=False)
print(dff.index)
print(dff.values)
# Out:
# Index(['Air_India', 'Vistara', 'SpiceJet', 'AirAsia', 'GO_FIRST', 'Indigo'], dtype='object', name='airline')
# [15.50423528 13.3266345  12.57976695  8.9417145   8.75537997  5.79519666]

# %%
# 19.2 seaborn : bar chart
import matplotlib.pyplot as plt
import seaborn as sns

sns_duration_groupby_airline = df.groupby("airline")["duration"].mean().sort_values(ascending=False)

sns_bar = sns.barplot(
    x = sns_duration_groupby_airline.index,
    y = sns_duration_groupby_airline.values,
    color = "yellow",
    edgecolor = "red"
)

for sns_bar_var in sns_bar.patches:
    sns_bar_height = sns_bar_var.get_height()
    sns_bar.text(
        sns_bar_var.get_x() + sns_bar_var.get_width()/2,
        sns_bar_height,
        str(int(sns_bar_height)),
        ha = "center",
        va = "bottom"
    )

plt.title("Duration per airline")
plt.xlabel("airline")
plt.ylabel("duration")
plt.show()

# %%
# 19.2 seaborn : bar chart (another method)

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
# 19.3 line chart
# Line Plot	    sns.lineplot()	    sns.lineplot(data=df, x="date", y="price")

import matplotlib.pyplot as plt
import seaborn as sns

num_flight_groupby_dayleft = df.groupby("days_left")["flight"].count().reset_index(name="count")

sns.lineplot(
    x = num_flight_groupby_dayleft["days_left"],
    y = num_flight_groupby_dayleft["count"],
    color = "green"
)

plt.title("number of flight by day left")
plt.xlabel("days left")
plt.ylabel("number of flight")
plt.show()

# %%
df.head(5)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
sns_pie_flight_by_arrival_time = df.groupby("arrival_time")["flight"].count().reset_index(name="flight_amount")
print(sns_pie_flight_by_arrival_time)
# Out:
#     arrival_time  flight_amount
# 0      Afternoon          38139
# 1  Early_Morning          15417
# 2        Evening          78323
# 3     Late_Night          14001
# 4        Morning          62735
# 5          Night          91538

# %%
# 19.4 pie chart
# !!! seaborn does not have built in pie chart function so we need to use matplotlip instead but we can use seanborn theme to make a good visual style

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
labels = sns_pie_flight_by_arrival_time["arrival_time"]
sizes = sns_pie_flight_by_arrival_time["flight_amount"].sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(7,7))
ax.pie(sizes, 
       labels=labels,
       autopct="%1.1f%%",
       textprops={"fontsize" : 10},
       startangle=90
       )
plt.title("Flight by arrival time")
# Out:
# Text(0.5, 1.0, 'Flight by arrival time')

# %%
df.head(5)
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
# 19.5 scatter plot
# Core syntax
# Scatter Plot	sns.scatterplot()	sns.scatterplot(data=df, x="duration", y="price")

import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(
    data= df,
    x= df["duration"],
    y= df["price"],
    hue= "airline",
    style= "airline"
)

plt.title("Relationship between price and duration")
# Out:
# Text(0.5, 1.0, 'Relationship between price and duration')
